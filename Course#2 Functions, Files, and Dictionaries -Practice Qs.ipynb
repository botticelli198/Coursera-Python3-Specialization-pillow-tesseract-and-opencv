# %% [markdown]
# # Files

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
num_words = 0

with open("emotion_words.txt", "r") as f:

    for line in f:
        wrd = line.split()
        num_words += len(wrd)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-7f0e75dc564d> in <module>
#       1 num_words = 0
#       2
# ----> 3 with open("emotion_words.txt", "r") as f:
#       4
#       5     for line in f:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'emotion_words.txt'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
num_lines = 0

with open("school_prompt.txt", "r") as f:
    for line in f:
        num_lines += 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
beginning_chars = 0 
with open("school_prompt.txt", "r") as f:
    beginning_chars = f.read(30)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
three = []
with open("school_prompt.txt","r") as f:
    for line in f:
        line = line.split()
        three.append(line[2])
         
#or 

three = []

with open('school_prompt.txt', 'r') as f:
    three = [line.split()[2] for line in f]
    print(three)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
emotions = []

with open("emotion_words.txt","r") as f:
    for line in f:
        emotions.append(line.split()[0])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
p_words = []
word = []

with open("school_prompt.txt","r") as f:
    word = f.read().split()

for i in word:
    if "p" in i:
        p_words.append(i)
#or 

fileref = open('school_prompt.txt', 'r')
words = fileref.read().split()
p_words = [word for word in words if 'p' in word]

# %% [markdown]
# # Dictionaries

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
f = open('scarlet.txt', 'r')
txt = f.read()
# now txt is one long string containing all the characters
letter_counts = {} # start with an empty dictionary
for c in txt:
    if c not in letter_counts:
        # we have not seen this character before, so initialize a counter for it
        letter_counts[c] = 0

    #whether we've seen it before or not, increment its counter
    letter_counts[c] = letter_counts[c] + 1

for c in letter_counts.keys():
    print(c + ": " + str(letter_counts[c]) + " occurrences")

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sentence = "The dog chased the rabbit into the forest but the rabbit was too quick."
words = sentence.split()
word_counts ={}
for word in words:
    if word not in word_counts:
        word_counts[word] = 0
    word_counts[word] += 1

print(word_counts)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
d = {'a': 194, 'b': 54, 'c':34, 'd': 44, 'e': 312, 'full':31}

ks = list(d.keys())


best_key = ks[0]

for k in ks:
    if d[k] > d[best_key]:
        best_key = k

print("key " + best_key + " has the highest value, " + str(d[best_key]))
# Out:
# key e has the highest value, 312

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
placement = "Beaches are cool places to visit in spring however the Mackinaw Bridge is near. Most people visit Mackinaw later since the island is a cool place to explore."

d = {}
for i in placement:
    if i not in d:
        d[i] = 0
    d[i] += 1


keys = list(d.keys())
min_value = keys[0]


for x in keys:
    if d[x] < d[min_value]:
        min_value = x
        
print(min_value)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
product = "iphone and android phones"

lett_d = {}

for i in product:
    if i not in lett_d:
        lett_d[i] = 0
    lett_d[i] += 1
    
keys = list(lett_d.keys())
max_value = keys[0]

for i in keys:
    if lett_d[i] > lett_d[max_value]:
        max_value = i

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
string1 = "There is a tide in the affairs of men, Which taken at the flood, leads on to fortune. Omitted, all the voyage of their life is bound in shallows and in miseries. On such a full sea are we now afloat. And we must take the current when it serves, or lose our ventures."
string1_lower = string1.lower()

print(string1_lower)

letter_counts = {}
for i in string1_lower:
    if i not in letter_counts:
        letter_counts[i] = 0
    letter_counts[i] += 1
    
print(letter_counts)
# Out:
# there is a tide in the affairs of men, which taken at the flood, leads on to fortune. omitted, all the voyage of their life is bound in shallows and in miseries. on such a full sea are we now afloat. and we must take the current when it serves, or lose our ventures.
# {'t': 19, 'h': 11, 'e': 29, 'r': 12, ' ': 53, 'i': 14, 's': 15, 'a': 17, 'd': 7, 'n': 15, 'f': 9, 'o': 17, 'm': 4, ',': 4, 'w': 6, 'c': 3, 'k': 2, 'l': 11, 'u': 8, '.': 4, 'v': 3, 'y': 1, 'g': 1, 'b': 1}

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
acopy = opposites.copy()
acopy['right'] = 'left'    # does not change opposites

# %% [markdown]
# # Functions

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def intro(x):
    return "Hello, my name is {} and I love SI 106.".format(x)

name = intro("Becky")
print(name)
# Out:
# Hello, my name is Becky and I love SI 106.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def most_common_letter(s):
    frequencies = count_freqs(s)
    return best_key(frequencies)

def count_freqs(st):
    d = {}
    for c in st:
        if c not in d:
             d[c] = 0
        d[c] = d[c] + 1
    return d

def best_key(dictionary):
    ks = dictionary.keys()
    best_key_so_far = list(ks)[0]  # Have to turn ks into a real list before using [] to select an item
    for k in ks:
        if dictionary[k] > dictionary[best_key_so_far]:
            best_key_so_far = k
    return best_key_so_far

print(most_common_letter("abbbbbbbbbbbccccddddd"))

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
pokemon = {'Rattata': 19, 'Machop': 66, 'Seel': 86, 'Volbeat': 86, 'Solrock': 126}
p_names = []
p_number = []
for k, v in pokemon.items():
    p_names.append(k)
    p_number.append(v)

print(pokemon.items())
# Out:
# dict_items([('Rattata', 19), ('Machop', 66), ('Seel', 86), ('Volbeat', 86), ('Solrock', 126)])

# %% [markdown]
# ## While Loop

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
count = 0
eve_nums =[]
    
while count < 16:
    if count % 2 == 0:
        eve_nums.append(count)
    count += 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
list1 = [8, 3, 4, 5, 6, 7, 9]

index = 0
accum = 0 
while index < len(list1):
    accum += list1[index]
    index += 1 

print(accum)
print(count)
# Out:
# 42
# 7

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def stop_at_four(list):
    list1 = []
    index = 0
    while index < len(list):
        if list[index] != 4:
            list1.append(list[index])
            index += 1
        else:
            break

    return list1
        

test = [1,6,8,0,6,3,4,5,2,9,9]


a = stop_at_four(test)

print(a)
# Out:
# [1, 6, 8, 0, 6, 3]

# %%
theSum = 0
x = -1
while x != 0:
    x = int(input("next number to add up (enter 0 if no more numbers): "))
    theSum = theSum + x

print(theSum)
# Out:
# next number to add up (enter 0 if no more numbers): 1
# next number to add up (enter 0 if no more numbers): 4
# next number to add up (enter 0 if no more numbers): 2
# next number to add up (enter 0 if no more numbers): 0
# 7

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# def checkout():
#     total = 0
#     count = 0
#     moreItems = True
#     while moreItems:
#         price = float(input('Enter price of item (0 when done): '))
#         if price > 0:
#             count = count + 1
#             total = total + price
#             print('Subtotal: $', total)
#         elif price < 0:
#             print ("No negative price!")
#         else:
#             moreItems = False
#
#     if count == 0:
#         print("you can’t compute an average without data!")
#         average = "error"
#     else:
#         average = total / count
#
#     print('Total items:', count)
#     print('Total $', total)
#     print('Average price per item: $', average)
#
# checkout()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def get_yes_or_no(message):
    valid_input = False
    while not valid_input:
        answer = input(message)
        answer = answer.upper() # convert to upper case
        if answer == 'Y' or answer == 'N':
            valid_input = True
        else:
            print('Please enter Y for yes or N for no.')
    return answer

response = get_yes_or_no('Do you like lima beans? Y)es or N)o: ')
if response == 'Y':
    print('Great! They are very healthy.')
else:
    print('Too bad. If cooked right, they are quite tasty.')
# Out:
# Do you like lima beans? Y)es or N)o: y
# Great! They are very healthy.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import random
import turtle

def isInScreen(w,t):
    leftBound = - w.window_width() / 2
    rightBound = w.window_width() / 2
    topBound = w.window_height() / 2
    bottomBound = -w.window_height() / 2

    turtleX = t.xcor()
    turtleY = t.ycor()

    stillIn = True
    if turtleX > rightBound or turtleX < leftBound:
        stillIn = False
    if turtleY > topBound or turtleY < bottomBound:
        stillIn = False

    return stillIn

t = turtle.Turtle()
wn = turtle.Screen()

t.shape('turtle')
while isInScreen(wn,t):
    coin = random.randrange(0, 2)
    if coin == 0:
        t.left(90)
    else:
        t.right(90)

    t.forward(50)

wn.exitonclick()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
counter = 0
three_nums = []
while counter <= 35:
    if counter % 3 == 0:
        three_nums.append(counter)
    counter += 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def check_nums(x):
    list1 = []
    index = 0
    while index < len(x):
        if x[index] != 7:
            list1.append(x[index])
        else:
            break 
        index += 1
    return list1

test = [1,6,8,0,6,3,4,5,7,2,9,9]


a = check_nums(test)

print(a)
# Out:
# [1, 6, 8, 0, 6, 3, 4, 5]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def beginning(x):
    list1 = []
    index = 0
    while index < 10:
        if x[index] == "bye":
            break
        else:
            list1.append(x[index])
        index += 1
    return list1

test = ['water', 'phone', 'home', 'chapstick', 'market', 'headphones', 'bye', 'stickie notes', 'snapchat', 'facebook', 'social media']
a = beginning(test)
print(a)
# Out:
# ['water', 'phone', 'home', 'chapstick', 'market', 'headphones']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
default = {2:3, 4:5, 6:8}
def test(x, y=True, dict1= default):
    if y is True:
        if x in dict1:
            return dict1.get(x)
    else:
        return False

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
default ={'apple': 2, 'pear': 1, 'fruit': 19, 'orange': 5, 'banana': 3, 'grapes': 2, 'watermelon': 7}

def checkingIfIn(x, direction = True, d = default):
    if direction == True:
        if x in d:
            return True
        else:
            return False
    else:
        if x not in d:
            return True
        else:
            return False

# %%
def checkingIfIn(a, direction = True, d = {'apple': 2, 'pear': 1, 'fruit': 19, 'orange': 5, 'banana': 3, 'grapes': 2, 'watermelon': 7}):
    if direction == True:
        if a in d:
            return d[a]
        else:
            return False
    else:
        if a not in d:
            return True
        else:
            return d[a]

# Call the function so that it returns False and assign that function call to the variable c_false
checkingIfIn("apple", False)
# Call the fucntion so that it returns True and assign it to the variable c_true

# Call the function so that the value of fruit is assigned to the variable fruit_ans

# Call the function using the first and third parameter so that the value 8 is assigned to the variable param_check
# Out:
# 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def checkingIfIn(a, direction = True, d = {'apple': 2, 'pear': 1, 'fruit': 19, 'orange': 5, 'banana': 3, 'grapes': 2, 'watermelon': 7}):
    if direction == True:
        if a in d:
            return d[a]
        else:
            return False
    else:
        if a not in d:
            return True
        else:
            return d[a]

# Call the function so that it returns False and assign that function call to the variable c_false
c_false = checkingIfIn("aple", True)
# Call the fucntion so that it returns True and assign it to the variable c_true
c_true = checkingIfIn("aple", False)

# Call the function so that the value of fruit is assigned to the variable fruit_ans
fruit_ans = checkingIfIn("fruit")
# Call the function using the first and third parameter so that the value 8 is assigned to the variable param_check
param_check = checkingIfIn("fruit", d={"fruit":8})

# %% [markdown]
# ## Sorting

# %%
L1 = [1, 7, 4, -2, 3]

def absolute(x):
    if x >= 0:
        return x
    else:
        return -x

L2 = sorted(L1, key=absolute)
print(L2)

#or in reverse order
print(sorted(L1, reverse=True, key=absolute))
# Out:
# [1, -2, 3, 4, 7]
# [7, 4, 3, -2, 1]

# %%
sorted("This is a test string from Andrew".split(), key=str.lower)
# Out:
# ['a', 'Andrew', 'from', 'is', 'string', 'test', 'This']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
ex_lst = ['hi', 'how are you', 'bye', 'apple', 'zebra', 'dance']
def second_let(x):
        return x[1]

func_sort = sorted(ex_lst, key=second_let)
# Out:
# ['dance', 'zebra', 'hi', 'how are you', 'apple', 'bye']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
nums = ['1450', '33', '871', '19', '14378', '32', '1005', '44', '8907', '16']


nums_sorted_lambda = sorted(nums, reverse=True, key=lambda x: x[-1])

print(nums_sorted_lambda)
# Out:
# ['19', '14378', '8907', '16', '1005', '44', '33', '32', '871', '1450']

# %% [markdown]
# ### the following code counts the frequencies of different numbers in the list.

# %%
L = ['E', 'F', 'B', 'A', 'D', 'I', 'I', 'C', 'B', 'A', 'D', 'D', 'E', 'D']

d = {}
for x in L:
    if x in d:
        d[x] = d[x] + 1
    else:
        d[x] = 1

y = sorted(d, key=lambda k: d[k], reverse=True)
print(d)
print(y)
for k in y:
    print("{} appears {} times".format(k, d[k]))
# Out:
# {'E': 2, 'F': 1, 'B': 2, 'A': 2, 'D': 4, 'I': 2, 'C': 1}
# ['D', 'E', 'B', 'A', 'I', 'F', 'C']
# D appears 4 times
# E appears 2 times
# B appears 2 times
# A appears 2 times
# I appears 2 times
# F appears 1 times
# C appears 1 times

# %% [markdown]
# ### For our second sort order, the property we want to sort by is the number of cities that begin with the letter ‘S’. The function defining this property is harder to express, requiring a filter and count accumulation pattern. So we are better off defining a separate, named function

# %%
def s_cities_count(city_list):
    ct = 0
    for city in city_list:
        if city[0] == "S":
            ct += 1
    return ct

states = {"Minnesota": ["St. Paul", "Minneapolis", "Saint Cloud", "Stillwater"],
          "Michigan": ["Ann Arbor", "Traverse City", "Lansing", "Kalamazoo"],
          "Washington": ["Seattle", "Tacoma", "Olympia", "Vancouver"]}

print(sorted(states, key=lambda x: s_cities_count(states[x])))
# Out:
# ['Michigan', 'Washington', 'Minnesota']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
medals = {'Japan':41, 'Russia':56, 'South Korea':21, 'United States':121, 'Germany':42, 'China':70}

top_three=sorted(medals, key=lambda x: medals[x], reverse=True)[0:3]

print(top_three)
# Out:
# ['United States', 'China', 'Russia']

# %%
groceries = {'apples': 5, 'pasta': 3, 'carrots': 12, 'orange juice': 2, 'bananas': 8, 'popcorn': 1, 'salsa': 3, 'cereal': 4, 'coffee': 5, 'granola bars': 15, 'onions': 7, 'rice': 1, 'peanut butter': 2, 'spinach': 9}
most_needed = sorted(groceries, key=lambda x: groceries[x])
print(most_needed)
# Out:
# ['popcorn', 'rice', 'orange juice', 'peanut butter', 'pasta', 'salsa', 'cereal', 'apples', 'coffee', 'onions', 'bananas', 'spinach', 'carrots', 'granola bars']

# %% [markdown]
# ## ![image.png](attachment:image.png)

# %%
def last_four(i):
    i = str(i)[-4:]
    return i

ids = [17573005, 17572342, 17579000, 17570002, 17572345, 17579329]

last_four(ids)
sorted_ids = sorted(ids, key=lambda x: last_four(x))

print(sorted_ids)
# Out:
# [17570002, 17572342, 17572345, 17573005, 17579000, 17579329]

# %% [markdown]
# ### this time do this using ONLY lambda and not using the function!

# %%
ids = [17573005, 17572342, 17579000, 17570002, 17572345, 17579329]
sorted_id = sorted(ids, key=lambda x: str(x)[-4:])

# %% [markdown]
# ## Project

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
punctuation_chars = ["'", '"', ",", ".", "!", ":", ";", '#', '@']
# lists of words to use
positive_words = []
with open("positive_words.txt") as pos_f:
    for lin in pos_f:
        if lin[0] != ';' and lin[0] != '\n':
            positive_words.append(lin.strip())


negative_words = []
with open("negative_words.txt") as pos_f:
    for lin in pos_f:
        if lin[0] != ';' and lin[0] != '\n':
            negative_words.append(lin.strip())


def strip_punctuation(x):
    for i in punctuation_chars:
        x = x.replace(i,"")
    return x

def get_pos(sentences):
    sentences = strip_punctuation(sentences)
    count = 0
    for word in sentences.split():
        if word in positive_words:
            count += 1
    return count

def get_neg(sentences):
    sentences = strip_punctuation(sentences)
    count = 0
    for word in sentences.split():
        if word in negative_words:
            count += 1
    return count


with open("project_twitter_data.csv", "r") as f:
    TwitData = f.readlines()
    TwitData = TwitData[1:]

result=open("resulting_data.csv", "w")

def WriteFile(result):
    result.write("Number of Retweets, Number of Replies, Positive Score, Negative Score, Net Score")
    result.write("\n")

    for line in TwitData:
        line=line.strip().split(',')
        result.write("{},{},{},{},{}".format(line[1], line[2],get_pos(line[0]),get_neg(line[0]),(get_pos(line[0])-get_neg(line[0]))))
        result.write("\n")
WriteFile(result)

result.close()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

result = pd.read_csv('resulting_data.csv')
result.columns = [x.strip() for x in result.columns] 
ax = sns.scatterplot(data=result, x="Net Score", y="Number of Retweets")
