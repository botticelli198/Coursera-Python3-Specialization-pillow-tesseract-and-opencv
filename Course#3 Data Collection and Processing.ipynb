# %%
a = '3459076'
print(a[:-2])
# Out:
# 34590

# %%
d = ['good morning', 'hello', 'chair', 'python', ['music', 'flowers', 'facebook', 'instagram', 'snapchat', ['On my Own', 'monster', 'Words dont come so easily', 'lead me right']], 'Stressed Out', 'Pauver Coeur', 'Reach for Tomorrow', 'mariners song', 'Wonder sleeps here']

for i in d:
    print(type(i))
    
m_list = []

for l1 in d:
    if type(l1) == str:
        if "m" in l1:
            m_list.append(l1)
    elif type(l1) == list:
        for l2 in l1:
            if type(l2) == str:
                if "m" in l2:
                    m_list.append(l2)
            elif type(l2) == list:
                for l3 in l2:
                    if "m" in l3:
                        m_list.append(l3)
                    
print(m_list)
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'list'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ['good morning', 'music', 'instagram', 'On my Own', 'monster', 'Words dont come so easily', 'lead me right', 'Reach for Tomorrow', 'mariners song']

# %% [markdown]
# https://www.reddit.com/r/learnpython/comments/cyv254/nested_dictionary/

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
pokemon = {'Trainer1':
          {'normal': {'rattatas':15, 'eevees': 2, 'ditto':1}, 'water': {'magikarps':3}, 'flying': {'zubats':8, 'pidgey': 12}},
          'Trainer2':
          {'normal': {'rattatas':25, 'eevees': 1}, 'water': {'magikarps':7}, 'flying': {'zubats':3, 'pidgey': 15}},
          'Trainer3':
          {'normal': {'rattatas':10, 'eevees': 3, 'ditto':2}, 'water': {'magikarps':2}, 'flying': {'zubats':3, 'pidgey': 20}},
          'Trainer4':
          {'normal': {'rattatas':17, 'eevees': 1}, 'water': {'magikarps':9}, 'flying': {'zubats':12, 'pidgey': 14}}}


# for trainer in pokemon:
#     for catagory in trainer:
#         if "rattatas" in catagory:
# #             r += 'rattatas'.get()
            
def count_pokemon(pokemon_type, pokemon_name):
    return sum(x.get(pokemon_type, {}).get(pokemon_name, 0) for x in pokemon.values())

print(count_pokemon('normal', 'rattatas'))
# Out:
# 67

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
big_list = [[['one', 'two'], ['seven', 'eight']], [['nine', 'four'], ['three', 'one']], [['two', 'eight'], ['seven', 'four']], [['five', 'one'], ['four', 'two']], [['six', 'eight'], ['two', 'seven']], [['three', 'five'], ['one', 'six']], [['nine', 'eight'], ['five', 'four']], [['six', 'three'], ['four', 'seven']]]

word_counts = {}

for li1 in big_list:
    for li2 in li1:
            for word in li2:
                if word in word_counts:
                    word_counts[word] += 1
                else:
                    word_counts[word] = 1
                    
print(word_counts)
# Out:
# {'one': 4, 'two': 4, 'seven': 4, 'eight': 4, 'nine': 2, 'four': 5, 'three': 3, 'five': 3, 'six': 3}

# %%
pokemon_go_data = {'bentspoon':
                  {'Rattata': 203, 'Pidgey': 120, 'Drowzee': 89, 'Squirtle': 35, 'Pikachu': 3, 'Eevee': 34, 'Magikarp': 300, 'Paras': 38},
                  'Laurne':
                  {'Pidgey': 169, 'Rattata': 245, 'Squirtle': 9, 'Caterpie': 38, 'Weedle': 97, 'Pikachu': 6, 'Nidoran': 44, 'Clefairy': 15, 'Zubat': 79, 'Dratini': 4},
                  'picklejarlid':
                  {'Rattata': 32, 'Drowzee': 15, 'Nidoran': 4, 'Bulbasaur': 3, 'Pidgey': 56, 'Weedle': 21, 'Oddish': 18, 'Magmar': 6, 'Spearow': 14},
                  'professoroak':
                  {'Charmander': 11, 'Ponyta': 9, 'Rattata': 107, 'Belsprout': 29, 'Seel': 19, 'Pidgey': 93, 'Shellder': 43, 'Drowzee': 245, 'Tauros': 18, 'Lapras': 18}}


sum_dic = {}

for player in pokemon_go_data.values():
    for key1 in player:
        if key1 in sum_dic:
            sum_dic[key1] += player.get(key1)
        else:
            sum_dic[key1] = player.get(key1)
            
print(sum_dic)

most_common_pokemon = max(sum_dic, key=sum_dic.get)

print(most_common_pokemon)


max_v = max(sum_dic.values())
most_common_pokemon = [k for k, v in sum_dic.items() if v==max_v]
print(most_common_pokemon)
# Out:
# {'Rattata': 587, 'Pidgey': 438, 'Drowzee': 349, 'Squirtle': 44, 'Pikachu': 9, 'Eevee': 34, 'Magikarp': 300, 'Paras': 38, 'Caterpie': 38, 'Weedle': 118, 'Nidoran': 48, 'Clefairy': 15, 'Zubat': 79, 'Dratini': 4, 'Bulbasaur': 3, 'Oddish': 18, 'Magmar': 6, 'Spearow': 14, 'Charmander': 11, 'Ponyta': 9, 'Belsprout': 29, 'Seel': 19, 'Shellder': 43, 'Tauros': 18, 'Lapras': 18}
# Rattata
# ['Rattata']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
nested_d = {'Beijing':{'China':51, 'USA':36, 'Russia':22, 'Great Britain':19}, 'London':{'USA':46, 'China':38, 'Great Britain':29, 'Russia':22}, 'Rio':{'USA':35, 'Great Britain':22, 'China':20, 'Germany':13}}

US_count = []

for city in nested_d.values():
    for country in city:
        if country == "USA":
            US_count.append(city.get('USA'))
            
print(US_count)
# Out:
# [36, 46, 35]

# %%
nested = {'data': ['finding', 23, ['exercises', 'hangout', 34]], 'window': ['part', 'whole', [], 'sum', ['math', 'calculus', 'algebra', 'geometry', 'statistics',['physics', 'chemistry', 'biology']]]}

# Check to see if the string data is a key in nested, if it is, assign True to the variable data, otherwise assign False.

if "data" in nested.keys():
    data = True
else:
    data = False

# Check to see if the integer 24 is in the value of the key data, if it is then assign to the variable twentyfour the value of True, otherwise False.


if 24 in nested.get('data'):
    twentyfour = True
else:
    twentyfour = False

# Check to see that the string 'whole' is not in the value of the key window. If it's not, then assign to the variable whole the value of True, otherwise False.
if 'whole' not in nested.get('window'):
    whole = True
else:
    whole = False
# Check to see if the string 'physics' is a key in the dictionary nested. If it is, assign to the variable physics, the value of True, otherwise False.

if 'physics' in nested.keys():
    physics = True
else:
    physics = False
# Out:
# False

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
nested_d = {'Beijing':{'China':51, 'USA':36, 'Russia':22, 'Great Britain':19}, 'London':{'USA':46, 'China':38, 'Great Britain':29, 'Russia':22}, 'Rio':{'USA':35, 'Great Britain':22, 'China':20, 'Germany':13}}

london_gold = nested_d.get('London').get('Great Britain')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
tester = {'info': [{"name": "Lauren", 'class standing': 'Junior', 'major': "Information Science"},{'name': 'Ayo', 'class standing': "Bachelor's", 'major': 'Information Science'}, {'name': 'Kathryn', 'class standing': 'Senior', 'major': 'Sociology'}, {'name': 'Nick', 'class standing': 'Junior', 'major': 'Computer Science'}, {'name': 'Gladys', 'class standing': 'Sophomore', 'major': 'History'}, {'name': 'Adam', 'major': 'Violin Performance', 'class standing': 'Senior'}]}

compri = [dic.get('name') for dic in tester['info']]
compri_1 = [dic['name'] for dic in tester['info']] #same as above line

print(compri)
print(compri_1)
# Out:
# ['Lauren', 'Ayo', 'Kathryn', 'Nick', 'Gladys', 'Adam']
# ['Lauren', 'Ayo', 'Kathryn', 'Nick', 'Gladys', 'Adam']

# %%
aa = ["apple","bananas","pear"]

#map
lst = list(map(lambda x: len(x), aa))

#list comprehansion (same as map)
lst1 = [len(x) for x in aa]
print (lst)
print(lst1)
# Out:
# [5, 7, 4]
# [5, 7, 4]

# %%
def lengths(strings):
    """lengths takes a list of strings as input and returns a list of numbers that are the lengths
    of strings in the input list. Use a list comprehension!"""
    # fill in this function's definition to make the test pass.
    lst = [len(x) for x in strings]
    return lst

lengths(["apple","bananas","pear"])
# Out:
# [5, 7, 4]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
things = [3, 5, -4, 7]
def positives_Acc(lst):
    post = [ x for x in lst if x>0]
    return post

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
L1 = [1, 2, 3, 4]
L2 = [4, 3, 2, 3]
L3 = [0, 5, 0, 5]


maxs = [max(x1, x2, x3) for x1, x2, x3 in zip(L1,L2,L3)]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
tester = {'info': [{"name": "Lauren", 'class standing': 'Junior', 'major': "Information Science"},{'name': 'Ayo', 'class standing': "Bachelor's", 'major': 'Information Science'}, {'name': 'Kathryn', 'class standing': 'Senior', 'major': 'Sociology'}, {'name': 'Nick', 'class standing': 'Junior', 'major': 'Computer Science'}, {'name': 'Gladys', 'class standing': 'Sophomore', 'major': 'History'}, {'name': 'Adam', 'major': 'Violin Performance', 'class standing': 'Senior'}]}

# tester1 = tester['info']
compri_sample = [x["name"] for x in tester["info"] if x["class standing"] == "Junior"]
print(compri_sample)
# Out:
# ['Lauren', 'Nick']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
L = [["hi", "bye"], ["hello", "goodbye"], ["hola", "adios", "bonjour", "au revoir"]]

result2 = [item for a in L for item in a ] 

print(result2)
# Out:
# ['hi', 'bye', 'hello', 'goodbye', 'hola', 'adios', 'bonjour', 'au revoir']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
tester = {'info': [
         {"name": "Lauren", 'class standing': 'Junior', 'major': "Information Science", 'important classes': ['SI 106', 'ENGLISH 125', 'SI 110', 'AMCULT 202']},
         {'name': 'Ayo', 'class standing': "Bachelor's", 'major': 'Information Science', "important classes": ['SI 106', 'SI 410', 'PSYCH 111']},
         {'name': 'Kathryn', 'class standing': 'Senior', 'major': 'Sociology', 'important classes': ['WOMENSTD 220', 'SOC 101', 'ENS 384']},
         {'name': 'Nick', 'class standing': 'Junior', 'major': 'Computer Science', "important classes": ['SOC 101', 'AMCULT 334', 'EECS 281']},
         {'name': 'Gladys', 'class standing': 'Sophomore', 'major': 'History', 'important classes': ['ENGLISH 125', 'HIST 259', 'ENGLISH 130']},
         {'name': 'Adam', 'major': 'Violin Performance', 'class standing': 'Senior', 'important classes': ['PIANO 101', 'STUDIO 300', 'THEORY 229', 'MUSC 356']}]}


class_sched = [ item for dic in tester['info'] for item in dic["important classes"]]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
nums = [[4, 3, 12, 10], [8, 7, 6], [5, 18, 15, 7, 11], [9, 4], [24, 20, 17], [3, 5]]

threes = [x for list in nums for x in list if x % 3 == 0]

# %%
lst_check = ['plums', 'watermelon', 'kiwi', 'strawberries', 'blueberries', 'peaches', 'apples', 'mangos', 'papaya']

def addition(x):
    for i in x:
        'Fruit: '+ i
        return i

aa = addition(lst_check)

print(aa)
# Out:
# papaya

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
lst_check = ['plums', 'watermelon', 'kiwi', 'strawberries', 'blueberries', 'peaches', 'apples', 'mangos', 'papaya']

map_testing = list(map(lambda x: 'Fruit: ' + x, lst_check))

print(map_testing)
# Out:
# ['Fruit: plums', 'Fruit: watermelon', 'Fruit: kiwi', 'Fruit: strawberries', 'Fruit: blueberries', 'Fruit: peaches', 'Fruit: apples', 'Fruit: mangos', 'Fruit: papaya']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
countries = ['Canada', 'Mexico', 'Brazil', 'Chile', 'Denmark', 'Botswana', 'Spain', 'Britain', 'Portugal', 'Russia', 'Thailand', 'Bangladesh', 'Nigeria', 'Argentina', 'Belarus', 'Laos', 'Australia', 'Panama', 'Egypt', 'Morocco', 'Switzerland', 'Belgium']

b_countries = list(filter(lambda x: x[0]=='B', countries))

print(b_countries)
# Out:
# ['Brazil', 'Botswana', 'Britain', 'Bangladesh', 'Belarus', 'Belgium']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
people = [('Snow', 'Jon'), ('Lannister', 'Cersei'), ('Stark', 'Arya'), ('Stark', 'Robb'), ('Lannister', 'Jamie'), ('Targaryen', 'Daenerys'), ('Stark', 'Sansa'), ('Tyrell', 'Margaery'), ('Stark', 'Eddard'), ('Lannister', 'Tyrion'), ('Baratheon', 'Joffrey'), ('Bolton', 'Ramsey'), ('Baelish', 'Peter')]

first_names = [ name[1] for name in people]
print(first_names)
# Out:
# ['Jon', 'Cersei', 'Arya', 'Robb', 'Jamie', 'Daenerys', 'Sansa', 'Margaery', 'Eddard', 'Tyrion', 'Joffrey', 'Ramsey', 'Peter']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
lst = [["hi", "bye"], "hello", "goodbye", [9, 2], 4]

lst2 = [i*2 for i in lst]
print(lst2)
# Out:
# [['hi', 'bye', 'hi', 'bye'], 'hellohello', 'goodbyegoodbye', [9, 2, 9, 2], 8]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
students = [('Tommy', 95), ('Linda', 63), ('Carl', 70), ('Bob', 100), ('Raymond', 50), ('Sue', 75)]

passed = [stu[0] for stu in students if stu[1] >= 70]

# %% [markdown]
# Challenge: ![image.png](attachment:image.png)

# %%
l1 = ['left', 'up', 'front']
l2 = ['right', 'down', 'back']

l3 = zip(l1, l2)
opposites = list(filter(lambda x: len(x[0])>3 and len(x[1])>3, l3))

print(opposites)
# Out:
# [('left', 'right'), ('front', 'back')]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
species = ['golden retriever', 'white tailed deer', 'black rhino', 'brown squirrel', 'field mouse', 'orangutan', 'sumatran elephant', 'rainbow trout', 'black bear', 'blue whale', 'water moccasin', 'giant panda', 'green turtle', 'blue jay', 'japanese beetle']

population = [10000, 90000, 1000, 2000000, 500000, 500, 1200, 8000, 12000, 2300, 7500, 100, 1800, 9500, 125000]

pop_info = list(zip(species, population))
endangered = [x[0] for x in pop_info if x[1] < 2500]

print(pop_info)
print(endangered)
# Out:
# [('golden retriever', 10000), ('white tailed deer', 90000), ('black rhino', 1000), ('brown squirrel', 2000000), ('field mouse', 500000), ('orangutan', 500), ('sumatran elephant', 1200), ('rainbow trout', 8000), ('black bear', 12000), ('blue whale', 2300), ('water moccasin', 7500), ('giant panda', 100), ('green turtle', 1800), ('blue jay', 9500), ('japanese beetle', 125000)]
# ['black rhino', 'orangutan', 'sumatran elephant', 'blue whale', 'giant panda', 'green turtle']

# %% [markdown]
# ## API and Fetching Pages

# %%
import requests
import json

page = requests.get("https://api.datamuse.com/words?rel_rhy=funny")
print(type(page))
print(page.text[:150]) # print the first 150 characters
print(page.url) # print the url that was fetched
print("------")
x = page.json() # turn page.text into a python object
print(type(x))
print("---first item in the list---")
print(x[0])
print("---the whole list, pretty printed---")
print(json.dumps(x, indent=2)) # pretty print the results
# Out:
# <class 'requests.models.Response'>
# [{"word":"money","score":4429,"numSyllables":2},{"word":"honey","score":1212,"numSyllables":2},{"word":"sunny","score":722,"numSyllables":2},{"word":"
# https://api.datamuse.com/words?rel_rhy=funny
# ------
# <class 'list'>
# ---first item in the list---
# {'word': 'money', 'score': 4429, 'numSyllables': 2}
# ---the whole list, pretty printed---
# [
#   {
#     "word": "money",
#     "score": 4429,
#     "numSyllables": 2
#   },
#   {
#     "word": "honey",
#     "score": 1212,
#     "numSyllables": 2
#   },
#   {
#     "word": "sunny",
#     "score": 722,
#     "numSyllables": 2
#   },
#   {
#     "word": "bunny",
#     "score": 707,
#     "numSyllables": 2
#   },
#   {
#     "word": "blini",
#     "score": 618,
#     "numSyllables": 2
#   },
#   {
#     "word": "gunny",
#     "score": 451,
#     "numSyllables": 2
#   },
#   {
#     "word": "tunny",
#     "score": 301,
#     "numSyllables": 2
#   },
#   {
#     "word": "sonny",
# ...

# %%
d = {'q': '"violins and guitars"', 'tbm': 'isch'}
results = requests.get("https://google.com/search", params=d)
print(results.url)
# Out:
# https://www.google.com/search?q=%22violins+and+guitars%22&tbm=isch

# %% [markdown]
# ### 24.8.2. Defining a function to make repeated invocations

# %%
# import statements for necessary Python modules
import requests

def get_rhymes(word):
    baseurl = "https://api.datamuse.com/words"
    params_diction = {} # Set up an empty dictionary for query parameters
    params_diction["rel_rhy"] = word
    params_diction["max"] = "3" # get at most 3 results
    resp = requests.get(baseurl, params=params_diction)
#     return resp.json()
    # return the top three words
    return [d['word'] for d in resp.json()]
    #return resp.json() # Return a python object (a list of dictionaries in this case)

print(get_rhymes("grateful"))
# Out:
# ['fateful', 'hateful', 'ungrateful']

# %%
import requests
baseurl ='https://www.google.com/search'
dic = {"tbm":'isch',"q":"violins and guitars"}
resp = requests.get(baseurl, params=dic)
print(resp.url)
print(resp.text[:150])
# Out:
# https://www.google.com/search?tbm=isch&q=violins+and+guitars
# <!doctype html><html itemscope="" itemtype="http://schema.org/SearchResultsPage" lang="en"><head><meta content="text/html; charset=UTF-8" http-equiv="

# %% [markdown]
# ## Test

# %%
import requests_with_caching
import json

def get_movies_from_tastedive(movie):
    baseurl = "https://tastedive.com/api/similar"
    params_diction = {}
    params_diction['q'] = movie
    params_diction['limit'] = 5
    params_diction['type'] = 'movies'
    resp = requests_with_caching.get(baseurl, params=params_diction)
    #return resp.json()
    return resp.json()

get_movies_from_tastedive("Bridesmaids")

#print(json.dumps(x, indent=2))
get_movies_from_tastedive("Black Panther")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-112-d98fb311fa7e> in <module>
# ----> 1 import requests_with_caching
#       2 import json
#       3
#       4 def get_movies_from_tastedive(movie):
#       5     baseurl = "https://tastedive.com/api/similar"
#
# ModuleNotFoundError: No module named 'requests_with_caching'

# %%
movies  = {'Similar': {'Info': [{'Name': 'Bridesmaids', 'Type': 'movie'}], 'Results': [{'Name': 'Baby Mama', 'Type': 'movie'}, {'Name': 'The Five-Year Engagement', 'Type': 'movie'}, {'Name': 'Bachelorette', 'Type': 'movie'}, {'Name': 'The Heat', 'Type': 'movie'}, {'Name': 'Date Night', 'Type': 'movie'}]}}
# print(json.dumps(x, indent=2))

import requests_with_caching
import json

def get_movies_from_tastedive(movie):
    baseurl = "https://tastedive.com/api/similar"
    params_diction = {}
    params_diction['q'] = movie
    params_diction['limit'] = 5
    params_diction['type'] = 'movies'
    resp = requests_with_caching.get(baseurl, params=params_diction)
    #return resp.json()
    return resp.json()


def extract_movie_titles(x):
    return [y["Name"] for y in x['Similar']['Results']]

def get_related_titles(x):
    list_1 = []
    for movie in x:
        aa = extract_movie_titles(get_movies_from_tastedive(movie))
        for movie2 in aa:
            if movie2 not in list_1:
                list_1.append(movie2)
    return list_1

print(get_related_titles(["Black Panther", "Captain Marvel"]))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-131-96b013ce6922> in <module>
#       2 # print(json.dumps(x, indent=2))
#       3
# ----> 4 import requests_with_caching
#       5 import json
#       6
#
# ModuleNotFoundError: No module named 'requests_with_caching'

# %%
import json
movies  = {'Similar': {'Info': [{'Name': 'Bridesmaids', 'Type': 'movie'}], 'Results': [{'Name': 'Baby Mama', 'Type': 'movie'}, {'Name': 'The Five-Year Engagement', 'Type': 'movie'}, {'Name': 'Bachelorette', 'Type': 'movie'}, {'Name': 'The Heat', 'Type': 'movie'}, {'Name': 'Date Night', 'Type': 'movie'}]}}

print(json.dumps(movies, indent=2))

def extract_movie_titles(x):
    return [y["Name"] for y in x['Similar']['Results']]
# Out:
# {
#   "Similar": {
#     "Info": [
#       {
#         "Name": "Bridesmaids",
#         "Type": "movie"
#       }
#     ],
#     "Results": [
#       {
#         "Name": "Baby Mama",
#         "Type": "movie"
#       },
#       {
#         "Name": "The Five-Year Engagement",
#         "Type": "movie"
#       },
#       {
#         "Name": "Bachelorette",
#         "Type": "movie"
#       },
#       {
#         "Name": "The Heat",
#         "Type": "movie"
#       },
#       {
#         "Name": "Date Night",
#         "Type": "movie"
#       }
#     ]
#   }
# }

# %%
# some invocations that we use in the automated tests; uncomment these if you are getting errors and want better error messages
import requests_with_caching
import json

def get_movie_data(movie):
    baseurl = "http://www.omdbapi.com/"
    params_diction = {}
    params_diction['t'] = movie
    params_diction['r'] = 'json'
    resp = requests_with_caching.get(baseurl, params=params_diction)
    #return resp.json()
    return resp.json()

get_movie_data("Venom")
# get_movie_data("Baby Mama")

# %%
m = {'Title': 'Black Panther', 'Year': '2018', 'Rated': 'PG-13', 'Released': '16 Feb 2018', 'Runtime': '134 min', 'Genre': 'Action, Adventure, Sci-Fi', 'Director': 'Ryan Coogler', 'Writer': 'Ryan Coogler, Joe Robert Cole, Stan Lee (based on the Marvel comics by), Jack Kirby (based on the Marvel Comics by)', 'Actors': "Chadwick Boseman, Michael B. Jordan, Lupita Nyong'o, Danai Gurira", 'Plot': "After the death of his father, Prince T'Challa ascends to the throne of the small African country of Wakanda. T'Challa is also Black Panther, superhero. Now not only must he govern his country but defeat a dangerous adversary.", 'Language': 'Swahili, Nama, English, Xhosa, Korean', 'Country': 'USA, South Africa, South Korea, Australia', 'Awards': '14 nominations.', 'Poster': 'https://m.media-amazon.com/images/M/MV5BMTg1MTY2MjYzNV5BMl5BanBnXkFtZTgwMTc4NTMwNDI@._V1_SX300.jpg', 'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.4/10'}, {'Source': 'Rotten Tomatoes', 'Value': '97%'}, {'Source': 'Metacritic', 'Value': '88/100'}], 'Metascore': '88', 'imdbRating': '7.4', 'imdbVotes': '415,699', 'imdbID': 'tt1825683', 'Type': 'movie', 'DVD': '15 May 2018', 'BoxOffice': '$501,105,037', 'Production': 'Marvel Studios', 'Website': 'https://www.facebook.com/BlackPantherMovie/', 'Response': 'True'}

print(json.dumps(m, indent=2))

# some invocations that we use in the automated tests; uncomment these if you are getting errors and want better error messages
# get_movie_rating(get_movie_data("Deadpool 2"))
# import requests_with_caching
import json

def get_movie_data(movie):
    baseurl = "http://www.omdbapi.com/"
    params_diction = {}
    params_diction['t'] = movie
    params_diction['r'] = 'json'
    resp = requests_with_caching.get(baseurl, params=params_diction)
    return resp.json()

def get_movie_rating(json):
    for rator in json['Ratings']:
        if rator['Source'] == 'Rotten Tomatoes':
            score = rator['Value'].replace("%", "")
            return int(score)
    return 0

print(get_movie_rating(m))
# Out:
# {
#   "Title": "Black Panther",
#   "Year": "2018",
#   "Rated": "PG-13",
#   "Released": "16 Feb 2018",
#   "Runtime": "134 min",
#   "Genre": "Action, Adventure, Sci-Fi",
#   "Director": "Ryan Coogler",
#   "Writer": "Ryan Coogler, Joe Robert Cole, Stan Lee (based on the Marvel comics by), Jack Kirby (based on the Marvel Comics by)",
#   "Actors": "Chadwick Boseman, Michael B. Jordan, Lupita Nyong'o, Danai Gurira",
#   "Plot": "After the death of his father, Prince T'Challa ascends to the throne of the small African country of Wakanda. T'Challa is also Black Panther, superhero. Now not only must he govern his country but defeat a dangerous adversary.",
#   "Language": "Swahili, Nama, English, Xhosa, Korean",
#   "Country": "USA, South Africa, South Korea, Australia",
#   "Awards": "14 nominations.",
#   "Poster": "https://m.media-amazon.com/images/M/MV5BMTg1MTY2MjYzNV5BMl5BanBnXkFtZTgwMTc4NTMwNDI@._V1_SX300.jpg",
#   "Ratings": [
#     {
# ...

# %%
import requests_with_caching
import json

def get_movies_from_tastedive(movie):
    baseurl = "https://tastedive.com/api/similar"
    params_diction = {}
    params_diction['q'] = movie
    params_diction['limit'] = 5
    params_diction['type'] = 'movies'
    resp = requests_with_caching.get(baseurl, params=params_diction)
    #return resp.json()
    return resp.json()


def extract_movie_titles(x):
    return [y["Name"] for y in x['Similar']['Results']]

def get_related_titles(x):
    list_1 = []
    for movie in x:
        aa = extract_movie_titles(get_movies_from_tastedive(movie))
        for movie2 in aa:
            if movie2 not in list_1:
                list_1.append(movie2)
    return list_1

def get_movie_data(movie):
    baseurl = "http://www.omdbapi.com/"
    params_diction = {}
    params_diction['t'] = movie
    params_diction['r'] = 'json'
    resp = requests_with_caching.get(baseurl, params=params_diction)
    return resp.json()

def get_movie_rating(json):
    for rator in json['Ratings']:
        if rator['Source'] == 'Rotten Tomatoes':
            score = rator['Value'].replace("%", "")
            return int(score)
    return 0

def get_sorted_recommendations(movies):
    all_movies = get_related_titles(movies)
    all_movies = sorted(
        all_movies, key = lambda movie:(get_movie_rating(get_movie_data(movie)), movie))
    return all_movies 

#get_sorted_recommendations(["Bridesmaids", "Sherlock Holmes"])
